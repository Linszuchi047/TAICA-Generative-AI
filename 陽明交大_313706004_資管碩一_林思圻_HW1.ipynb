# %% [markdown]
# <a href="https://colab.research.google.com/github/Linszuchi047/TAICA-Generative-AI/blob/master/%E9%99%BD%E6%98%8E%E4%BA%A4%E5%A4%A7_313706004_%E8%B3%87%E7%AE%A1%E7%A2%A9%E4%B8%80_%E6%9E%97%E6%80%9D%E5%9C%BB_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #畫函數圖形

# %% [markdown]
# 🦋 使用 Python 繪製蝴蝶形狀曲線
# 此程式碼使用 NumPy 和 Matplotlib 繪製了一條類似蝴蝶形狀的曲線，主要透過數學函數計算 (x, y) 座標，然後將其繪製成圖形。
#
# 📌 主要概念
# 數學函數：
# 這條蝴蝶曲線的 (x, y) 座標是根據特定數學函數計算出來的。
# x 和 y 的公式使用 t 參數來計算，並包含指數函數、三角函數和冪函數的組合。
# Matplotlib 繪圖：
# 透過 plt.plot() 繪製 (x, y) 曲線。
# 設定標題、標籤、軸向比例等，使圖形更加清晰。

# %%
# prompt: 畫出像蝴蝶的函數圖形

import numpy as np
import matplotlib.pyplot as plt

# Define the function for a butterfly-like shape
def butterfly_function(t):
    x = np.sin(t) * (np.exp(np.cos(t)) - 2 * np.cos(4 * t) - np.sin(t / 12) ** 5)
    y = np.cos(t) * (np.exp(np.cos(t)) - 2 * np.cos(4 * t) - np.sin(t / 12) ** 5)
    return x, y

# Generate a range of t values
t = np.linspace(0, 12 * np.pi, 500)

# Calculate x and y values using the butterfly function
x, y = butterfly_function(t)

# Create the plot
plt.figure(figsize=(8, 8))
plt.plot(x, y, color='blue')

# Customize the plot (optional)
plt.title("Butterfly-like Function")
plt.xlabel("x")
plt.ylabel("y")
plt.axis('equal')  # Ensure the x and y axes have the same scale
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box') # Maintain aspect ratio
plt.show()
